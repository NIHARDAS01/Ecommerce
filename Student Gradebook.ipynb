# %% [markdown]
# <a href="https://colab.research.google.com/github/NIHARDAS01/Ecommerce/blob/main/Student%20Gradebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Gradebook Program

name = input("Enter Student Name: ")
roll = input("Enter Roll Number: ")

math = int(input("Enter Math Marks: "))
science = int(input("Enter Science Marks: "))
english = int(input("Enter English Marks: "))

total = math + science + english
percentage = total / 3

if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "F"

print("\n----- Grade Report -----")
print("Name:", name)
print("Roll No:", roll)
print("Total:", total)
print("Percentage:", percentage)
print("Grade:", grade)
# Out:
# Enter Student Name: Nihar
# Enter Roll Number: 151
# Enter Math Marks: 79
# Enter Science Marks: 88
# Enter English Marks: 82
#
# ----- Grade Report -----
# Name: Nihar
# Roll No: 151
# Total: 249
# Percentage: 83.0
# Grade: A
